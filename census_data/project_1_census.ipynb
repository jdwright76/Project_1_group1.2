# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
population = pd.read_csv("nst-est2018-01.csv")

# %%
population_df = pd.DataFrame(population)
pd.options.display.float_format = '{:,}'.format
population.head(20)
# Out:
#    table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)  \
# 0   Table 1. Annual Estimates of the Resident Popu...
# 1                                     Geographic Area
# 2                                                 NaN
# 3                                       United States
# 4                                           Northeast
# 5                                             Midwest
# 6                                               South
# 7                                                West
# 8                                            .Alabama
# 9                                             .Alaska
# 10                                           .Arizona
# 11                                          .Arkansas
# 12                                        .California
# 13                                          .Colorado
# 14                                       .Connecticut
# ...

# %%
population_years = population_df.drop(['Unnamed: 1', 'Unnamed: 2'], axis=1)

# %%
population_years.drop(population_years.head(8).index, inplace=True)
population_years.head()
# Out:
#    table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)  \
# 8                                            .Alabama
# 9                                             .Alaska
# 10                                           .Arizona
# 11                                          .Arkansas
# 12                                        .California
#
#      Unnamed: 3 Unnamed: 4   Unnamed: 5   Unnamed: 6   Unnamed: 7  \
# 8   4,757,938.0    4785448  4,798,834.0  4,815,564.0  4,830,460.0
# 9     698,895.0     713906    722,038.0    730,399.0    737,045.0
# 10  6,343,154.0    6407774  6,473,497.0  6,556,629.0  6,634,999.0
# 11  2,896,843.0    2921978  2,940,407.0  2,952,109.0  2,959,549.0
# 12 36,961,229.0   37320903 37,641,823.0 37,960,782.0 38,280,824.0
#
#      Unnamed: 8   Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12
# 8   4,842,481.0  4,853,160.0  4,864,745.0  4,875,120.0  4,887,871.0
# ...

# %%
population_years.columns = ['State', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']
population_years.head()
# Out:
#           State         2009      2010         2011         2012         2013  \
# 8      .Alabama  4,757,938.0   4785448  4,798,834.0  4,815,564.0  4,830,460.0
# 9       .Alaska    698,895.0    713906    722,038.0    730,399.0    737,045.0
# 10     .Arizona  6,343,154.0   6407774  6,473,497.0  6,556,629.0  6,634,999.0
# 11    .Arkansas  2,896,843.0   2921978  2,940,407.0  2,952,109.0  2,959,549.0
# 12  .California 36,961,229.0  37320903 37,641,823.0 37,960,782.0 38,280,824.0
#
#            2014         2015         2016         2017         2018
# 8   4,842,481.0  4,853,160.0  4,864,745.0  4,875,120.0  4,887,871.0
# 9     736,307.0    737,547.0    741,504.0    739,786.0    737,438.0
# 10  6,733,840.0  6,833,596.0  6,945,452.0  7,048,876.0  7,171,646.0
# 11  2,967,726.0  2,978,407.0  2,990,410.0  3,002,997.0  3,013,825.0
# 12 38,625,139.0 38,953,142.0 39,209,127.0 39,399,349.0 39,557,045.0

# %%
population_years['State'] = population_years.State.str.replace('.','')
population_years.head()
# Out:
#          State         2009      2010         2011         2012         2013  \
# 8      Alabama  4,757,938.0   4785448  4,798,834.0  4,815,564.0  4,830,460.0
# 9       Alaska    698,895.0    713906    722,038.0    730,399.0    737,045.0
# 10     Arizona  6,343,154.0   6407774  6,473,497.0  6,556,629.0  6,634,999.0
# 11    Arkansas  2,896,843.0   2921978  2,940,407.0  2,952,109.0  2,959,549.0
# 12  California 36,961,229.0  37320903 37,641,823.0 37,960,782.0 38,280,824.0
#
#            2014         2015         2016         2017         2018
# 8   4,842,481.0  4,853,160.0  4,864,745.0  4,875,120.0  4,887,871.0
# 9     736,307.0    737,547.0    741,504.0    739,786.0    737,438.0
# 10  6,733,840.0  6,833,596.0  6,945,452.0  7,048,876.0  7,171,646.0
# 11  2,967,726.0  2,978,407.0  2,990,410.0  3,002,997.0  3,013,825.0
# 12 38,625,139.0 38,953,142.0 39,209,127.0 39,399,349.0 39,557,045.0

# %%
state_2 = {'Alabama':'AL', 'Alaska':'AK', 'Arizona':'AZ', 'Arkansas': 'AR', 'California':'CA',
          'Colorado':'CO', 'Connecticut':'CT', 'Delaware':'DE', 'Florida':'FL', 'Georgia':'GA',
          'Hawaii':'HI', 'Idaho':'ID', 'Illinois':'IL', 'Indiana':'IN', 'Iowa': 'IA', 'Kansas':'KS',
           'Kentucky':'KY', 'Louisiana':'LA', 'Maine':'ME', 'Maryland':'MD', 'Massachusetts':'MA',
          'Michigan':'MI', 'Minnesota':'MN', 'Missouri':'MO', 'Mississippi':'MS', 'Montana':'MT',
          "Nebraska":'NE', 'Nevada':'NV', 'New Hampshire':'NH','New Jersey':'NJ', 'New Mexico':'NM',
          'New York':'NY', 'North Carolina':'NC', 'North Dakota':'ND', 'Ohio':'OH', 'Oklahoma':'OK',
          'Oregon':'OR', 'Pennsylvania':'PA', 'Rhode Island':'RI', 'South Carolina':'SC', 'South Dakota':'SD',
          'Tennessee':'TN', 'Texas':'TX', 'Utah':'UT', 'Vermont':'VT', 'Virginia':'VA', 'Washington':'WA',
          'West Virginia':'WV', 'Wisconsin':'WI', 'Wyoming':'WY', 'District of Columbia':'DC'}

# %%
population_years['State_Abbr']=population_years['State'].map(state_2)

# %%
population_years[['2009','2010','2011','2012','2013','2014','2015','2016','2017','2018']]=population_years[['2009','2010','2011','2012','2013','2014','2015','2016','2017','2018']].astype(float)

# %%
population_years.dtypes
# Out:
# State          object
# 2009          float64
# 2010          float64
# 2011          float64
# 2012          float64
# 2013          float64
# 2014          float64
# 2015          float64
# 2016          float64
# 2017          float64
# 2018          float64
# State_Abbr     object
# dtype: object

# %%
#population_years.loc['Total'] = population_years.sum()
#population_years
total = population_years.apply(np.sum)
total['State'] = 'Total'
population_total = population_years.append(pd.DataFrame(total.values, index=total.keys()).T, ignore_index=True)
population_total
# Out:
#                    State          2009          2010          2011  \
# 0                Alabama   4,757,938.0   4,785,448.0   4,798,834.0
# 1                 Alaska     698,895.0     713,906.0     722,038.0
# 2                Arizona   6,343,154.0   6,407,774.0   6,473,497.0
# 3               Arkansas   2,896,843.0   2,921,978.0   2,940,407.0
# 4             California  36,961,229.0  37,320,903.0  37,641,823.0
# 5               Colorado   4,972,195.0   5,048,281.0   5,121,771.0
# 6            Connecticut   3,561,807.0   3,579,125.0   3,588,023.0
# 7               Delaware     891,730.0     899,595.0     907,316.0
# 8   District of Columbia     592,228.0     605,085.0     619,602.0
# 9                Florida  18,652,644.0  18,845,785.0  19,093,352.0
# 10               Georgia   9,620,846.0   9,711,810.0   9,801,578.0
# 11                Hawaii   1,346,717.0   1,363,963.0   1,379,252.0
# 12                 Idaho   1,554,439.0   1,570,773.0   1,583,828.0
# ...

# %%
population_total.to_csv("Population by State -2009-18.csv", mode='a',index=False)
