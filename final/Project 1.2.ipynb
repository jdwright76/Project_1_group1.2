# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
shelter_data = pd.read_csv("combdata.csv")
population = pd.read_csv("Population by State -2009-18.csv")
homeless_pop = pd.read_csv("HUD Homeless Data.csv")

# %%
#combined_HUD_df = pd.merge(shelter_data, population,homeless_pop, how='outer', on='State')
homeless_pop
# Out:
#     State  Year  Overall Homeless  Sheltered Total Homeless  \
# 0      AK  2009              1992                      1665
# 1      AK  2010              1863                      1671
# 2      AK  2011              1913                      1760
# 3      AK  2012              1913                      1716
# 4      AK  2013              1946                      1741
# 5      AK  2014              1784                      1639
# 6      AK  2015              1956                      1639
# 7      AK  2016              1940                      1498
# 8      AK  2017              1845                      1551
# 9      AK  2018              2016                      1707
# 10     AL  2009              6080                      3913
# 11     AL  2010              6046                      3891
# 12     AL  2011              5209                      3749
# 13     AL  2012              5209                      3664
# 14     AL  2013              4689                      3246
# ...
