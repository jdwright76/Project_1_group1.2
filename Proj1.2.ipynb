# %%
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from functools import reduce

# %%
Sh09_df = pd.read_csv("2007-2018-HIC-Counts-by-State_2009.csv", usecols=[0,1,4], header=0, names=["State","Total Beds 2009","Participation 2009"])
Sh10_df = pd.read_csv("2007-2018-HIC-Counts-by-State_2010.csv", usecols=[0,1,4], header=0, names=["State","Total Beds 2010","Participation 2010"])
Sh11_df = pd.read_csv("2007-2018-HIC-Counts-by-State_2011.csv", usecols=[0,1,4], header=0, names=["State","Total Beds 2011","Participation 2011"])
Sh12_df = pd.read_csv("2007-2018-HIC-Counts-by-State_2012.csv", usecols=[0,1,4], header=0, names=["State","Total Beds 2012","Participation 2012"])
Sh13_df = pd.read_csv("2007-2018-HIC-Counts-by-State_2013.csv", usecols=[0,1,4], header=0, names=["State","Total Beds 2013","Participation 2013"])
Sh14_df = pd.read_csv("2007-2018-HIC-Counts-by-State_2014.csv", usecols=[0,1,4], header=0, names=["State","Total Beds 2014","Participation 2014"])
Sh15_df = pd.read_csv("2007-2018-HIC-Counts-by-State_2015.csv", usecols=[0,1,4], header=0, names=["State","Total Beds 2015","Participation 2015"])
Sh16_df = pd.read_csv("2007-2018-HIC-Counts-by-State_2016.csv", usecols=[0,1,4], header=0, names=["State","Total Beds 2016","Participation 2016"])
Sh17_df = pd.read_csv("2007-2018-HIC-Counts-by-State_2018.csv", usecols=[0,1,4], header=0, names=["State","Total Beds 2017","Participation 2017"])
Sh18_df = pd.read_csv("2007-2018-HIC-Counts-by-State_2018.csv", usecols=[0,1,4], header=0, names=["State","Total Beds 2018","Participation 2018"])

# %%
df = pd.concat([Sh17_df,Sh18_df], ignore_index=True)
df
# Out:
# C:\Users\John Wright\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#     Participation 2017 Participation 2018  State  Total Beds 2017  \
# 0               72.53%                NaN     AK           1940.0
# 1               51.22%                NaN     AL           3188.0
# 2               29.00%                NaN     AR           2362.0
# 3               69.01%                NaN     AZ           6683.0
# 4               64.57%                NaN     CA          43548.0
# 5               48.37%                NaN     CO           7532.0
# 6               87.91%                NaN     CT           3417.0
# ...

# %%
dfs = [Sh09_df, Sh10_df, Sh11_df, Sh12_df, Sh13_df, Sh14_df, Sh15_df, Sh16_df, Sh17_df, Sh18_df]
comb_sh_df = reduce(lambda left,right:pd.merge(left,right,on="State"), dfs)
comb_sh_df.head()
# Out:
#   State Total Beds 2009 Participation 2009 Total Beds 2010 Participation 2010  \
# 0    AK           1,697             74.50%           1,805             74.00%
# 1    AL           4,065             42.20%           4,221             43.70%
# 2    AR           1,802             74.70%           2,700             69.10%
# 3    AZ           9,066             84.40%           8,914             87.40%
# 4    CA          52,397             64.00%          50,282             64.00%
#
#   Total Beds 2011 Participation 2011 Total Beds 2012 Participation 2012  \
# 0           1,939             81.90%           1,877             83.50%
# 1           4,497             51.80%           4,297             48.20%
# 2           2,710             67.20%           2,662             64.60%
# 3           8,748             86.10%           9,238             86.20%
# 4          49,657             70.20%          47,144             75.70%
#
# ...

# %%
# combined_total = pd.merge(Sh09_df, Sh10_df, on="State")

# combined_df1 = reduce(lambda one, two : pd.merge(one, two, on ="State"), [Sh09_df, Sh10_df, Sh11_df])
# combined_df2 = reduce(lambda three, four : pd.merge(three, four, on ="State"), [combined_df1, Sh12_df, Sh13_df])
# combined_df3 = reduce(lambda five, six : pd.merge(five, six, on ="State"), [combined_df2, Sh14_df, Sh15_df])
# combined_df4 = reduce(lambda seven, eight : pd.merge(seven, eight, on ="State"), [combined_df3, Sh16_df, Sh17_df])
# combined_df5 = reduce(lambda nine, ten : pd.merge(nine, ten, on ="State"), [combined_df4, Sh18_df])

# combined_df5.head()

# %%
# CYData_df = pd.read_csv("combdata.csv")
# CYData_df.head()
# pd.DataFrame(Sh18_df)

# %%
# Sh09_df = pd.read_csv("2007-2018-HIC-Counts-by-State_2009.csv").rename(columns={'Total Year-Round Beds (ES,TH,SH)':'Total Beds 2009','HMIS Participation Rate (ES,TH,SH)':'Participation 2009'})
# Sh10_df = pd.read_csv("2007-2018-HIC-Counts-by-State_2010.csv").rename(columns={'Total Year-Round Beds (ES,TH,SH)':'Total Beds 2010','HMIS Participation Rate (ES,TH,SH)':'Participation 2010'})
# Sh11_df = pd.read_csv("2007-2018-HIC-Counts-by-State_2011.csv").rename(columns={'Total Year-Round Beds (ES,TH,SH)':'Total Beds 2011','HMIS Participation Rate (ES,TH,SH)':'Participation 2011'})
# Sh12_df = pd.read_csv("2007-2018-HIC-Counts-by-State_2012.csv").rename(columns={'Total Year-Round Beds (ES,TH,RRH,SH)':'Total Beds 2012','HMIS Participation Rate (ES,TH,RRH,SH)':'Participation 2012'})
# Sh13_df = pd.read_csv("2007-2018-HIC-Counts-by-State_2013.csv").rename(columns={'Total Year-Round Beds (ES,TH,SH)':'Total Beds 2013','HMIS Participation Rate (ES,TH,SH)':'Participation 2013'})
# Sh14_df = pd.read_csv("2007-2018-HIC-Counts-by-State_2014.csv").rename(columns={'Total Year-Round Beds (ES,TH,SH)':'Total Beds 2014','HMIS Participation Rate (ES,TH,SH)':'Participation 2014'})
# Sh15_df = pd.read_csv("2007-2018-HIC-Counts-by-State_2015.csv").rename(columns={'Total Year-Round Beds (ES,TH,SH)':'Total Beds 2015','HMIS Participation Rate (ES,TH,SH)':'Participation 2015'})
# Sh16_df = pd.read_csv("2007-2018-HIC-Counts-by-State_2016.csv").rename(columns={'Total Year-Round Beds (ES,TH,SH)':'Total Beds 2016','HMIS Participation Rate (ES,TH,SH)':'Participation 2016'})
# Sh17_df = pd.read_csv("2007-2018-HIC-Counts-by-State_2017.csv").rename(columns={'Total Year-Round Beds (ES,TH,SH)':'Total Beds 2017','HMIS Participation Rate (ES,TH,SH)':'Participation 2017'})
# Sh18_df = pd.read_csv("2007-2018-HIC-Counts-by-State_2018.csv").rename(columns={'Total Year-Round Beds (ES,TH,SH)':'Total Beds 2018','HMIS Participation Rate (ES,TH,SH)':'Participation 2018'})

# %%
# Sh09_df = Shelters_09_df.rename(columns={'Total Year-Round Beds (ES,TH,SH)':'Total Beds 2009','HMIS Participation Rate (ES,TH,SH)':'Participation 2009'})
# Sh10_df = Shelters_10_df.rename(columns={'Total Year-Round Beds (ES,TH,SH)':'Total Beds 2010','HMIS Participation Rate (ES,TH,SH)':'Participation 2010'})
# Sh11_df = Shelters_11_df.rename(columns={'Total Year-Round Beds (ES,TH,SH)':'Total Beds 2011','HMIS Participation Rate (ES,TH,SH)':'Participation 2011'})
# Sh12_df = Shelters_12_df.rename(columns={'Total Year-Round Beds (ES,TH,SH)':'Total Beds 2012','HMIS Participation Rate (ES,TH,SH)':'Participation 2012'})
# Sh13_df = Shelters_13_df.rename(columns={'Total Year-Round Beds (ES,TH,SH)':'Total Beds 2013','HMIS Participation Rate (ES,TH,SH)':'Participation 2013'})
# Sh14_df = Shelters_14_df.rename(columns={'Total Year-Round Beds (ES,TH,SH)':'Total Beds 2014','HMIS Participation Rate (ES,TH,SH)':'Participation 2014'})
# Sh15_df = Shelters_15_df.rename(columns={'Total Year-Round Beds (ES,TH,SH)':'Total Beds 2015','HMIS Participation Rate (ES,TH,SH)':'Participation 2015'})
# Sh16_df = Shelters_16_df.rename(columns={'Total Year-Round Beds (ES,TH,SH)':'Total Beds 2016','HMIS Participation Rate (ES,TH,SH)':'Participation 2016'})
# Sh17_df = Shelters_17_df.rename(columns={'Total Year-Round Beds (ES,TH,SH)':'Total Beds 2017','HMIS Participation Rate (ES,TH,SH)':'Participation 2017'})
# Sh18_df = Shelters_18_df.rename(columns={'Total Year-Round Beds (ES,TH,SH)':'Total Beds 2018','HMIS Participation Rate (ES,TH,SH)':'Participation 2018'})

# %%
# merged_year_df = combined_df5[['State','Total Beds 2009','Participation 2009','Total Beds 2010','Participation 2010','Total Beds 2011','Participation 2011','Total Beds 2012','Participation 2012,]]
# merged_year_df

# %%
#'Total Beds 2009', 'Participation 2009', 'Total Beds 2010', 'Participation 2010', 'Total Beds 2011', 'Participation 2011', 'Total Beds 2012', 'Participation 2012', 'Total Beds 2013', 'Participation 2013', 'Total Beds 2014', 'Participation 2014', 'Total Beds 2015', 'Participation 2015', 'Total Beds 2016', 'Participation 2016','Total Beds 2017', 'Participation 2017', 'Total Beds 2018', 'Participation 2018']]

# %%
# Sh09_df = Sh09_df[["State", 'Total Beds 2009', 'Participation 2009' ]]
# Sh10_df = Sh10_df[["State", 'Total Beds 2010', 'Participation 2010' ]]
# Sh11_df = Sh11_df[["State", 'Total Beds 2011', 'Participation 2011' ]]
# Sh12_df = Sh12_df[["State", 'Total Beds 2012', 'Participation 2012' ]]
# Sh13_df = Sh13_df[["State", 'Total Beds 2013', 'Participation 2013' ]]
# Sh14_df = Sh14_df[["State", 'Total Beds 2014', 'Participation 2014' ]]
# Sh15_df = Sh15_df[["State", 'Total Beds 2015', 'Participation 2015' ]]
# Sh16_df = Sh16_df[["State", 'Total Beds 2016', 'Participation 2016' ]]
# Sh17_df = Sh17_df[["State", 'Total Beds 2017', 'Participation 2017' ]]
# Sh18_df = Sh18_df[["State", 'Total Beds 2018', 'Participation 2018' ]]

# %%
# combined_F = pd.merge(combined_A, combined_B, on='State')
# combined_G= pd.merge(combined_C, combined_D, on='State')
# combined_H = pd.merge(combined_F, combined_G, on='State')

# %%
# combined_years = pd.merge(combined_H, combined_E, on='State')

# %%
# Shelters_11_df, Shelters_12_df, Shelters_13_df, Shelters_14_df, Shelters_15_df, Shelters_16_df, Shelters_17_df, Shelters_18_df

# %%
# df_list0 = [Sh09_df, Sh10_df, Sh11_df]
# df_list2 = [Sh12_df, Sh13_df, Sh14_df]
# df_list3 = [Sh15_df, Sh16_df, Sh17_df]
